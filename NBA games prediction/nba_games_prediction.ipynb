# %%
# %pip install nba_api
# Out:
# Requirement already satisfied: nba_api in c:\users\sandh\anaconda3\lib\site-packages (1.1.11)
# Requirement already satisfied: requests in c:\users\sandh\anaconda3\lib\site-packages (from nba_api) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sandh\anaconda3\lib\site-packages (from requests->nba_api) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandh\anaconda3\lib\site-packages (from requests->nba_api) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandh\anaconda3\lib\site-packages (from requests->nba_api) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sandh\anaconda3\lib\site-packages (from requests->nba_api) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %%
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2020', league_id_nullable='00') 
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     42021  1610612738               BOS         Boston Celtics  0042100406
# 1     42021  1610612744               GSW  Golden State Warriors  0042100406
# 2     42021  1610612744               GSW  Golden State Warriors  0042100405
# 3     42021  1610612738               BOS         Boston Celtics  0042100405
# 4     42021  1610612744               GSW  Golden State Warriors  0042100404
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2022-06-16  BOS vs. GSW  L  239   90  ...   0.917    11    30   41   27
# 1  2022-06-16    GSW @ BOS  W  241  103  ...   1.000    15    29   44   27
# 2  2022-06-13  GSW vs. BOS  W  240  104  ...   0.867     4    35   39   23
# 3  2022-06-13    BOS @ GSW  L  238   94  ...   0.677     8    39   47   18
# 4  2022-06-10    GSW @ BOS  W  241  107  ...   0.800    16    39   55   20
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    8    8   22  16       -13.0
# 1   13    7   15  20        13.0
# 2    9    2    6  28        10.0
# 3    2    2   18  16       -10.0
# 4   10    5   16  21        10.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 'PLUS_MINUS' is the most important feature for our prediction

# %% [markdown]
# # Cleaning and Exploring data

# %%
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
games = games[['TEAM_NAME', 'GAME_ID',
       'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

# %%
games
# Out:
#                   TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  \
# 0            Boston Celtics  0042100406  2022-06-16  BOS vs. GSW  L
# 1     Golden State Warriors  0042100406  2022-06-16    GSW @ BOS  W
# 2     Golden State Warriors  0042100405  2022-06-13  GSW vs. BOS  W
# 3            Boston Celtics  0042100405  2022-06-13    BOS @ GSW  L
# 4     Golden State Warriors  0042100404  2022-06-10    GSW @ BOS  W
# ...                     ...         ...         ...          ... ..
# 6147   New Orleans Pelicans  0021900723  2020-01-31  NOP vs. MEM  W
# 6148           Phoenix Suns  0021900725  2020-01-31  PHX vs. OKC  L
# 6149  Oklahoma City Thunder  0021900725  2020-01-31    OKC @ PHX  W
# 6150        Detroit Pistons  0021900720  2020-01-31  DET vs. TOR  L
# 6151        Toronto Raptors  0021900720  2020-01-31    TOR @ DET  W
#
#       PLUS_MINUS
# 0          -13.0
# 1           13.0
# 2           10.0
# 3          -10.0
# 4           10.0
# ...          ...
# 6147        28.0
# 6148        -4.0
# 6149         4.0
# 6150       -13.0
# 6151        13.0
#
# [6152 rows x 6 columns]

# %% [markdown]
# ### Final dataframe:
# 1. one row for one game
# 2. two columns:
#     1. result of game: target
#     2. score stat comparing 2 teams: feature

# %%
import pandas as pd

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6152 entries, 0 to 6151
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM_NAME   6152 non-null   object
#  1   GAME_ID     6152 non-null   object
#  2   GAME_DATE   6152 non-null   object
#  3   MATCHUP     6152 non-null   object
#  4   WL          6152 non-null   object
#  5   PLUS_MINUS  6152 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 288.5+ KB

# %% [markdown]
# **We need to convert Dtype of GAME_DATE to datetime**

# %%
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

# %%
games['GAME_DATE']
# Out:
# 0      2022-06-16
# 1      2022-06-16
# 2      2022-06-13
# 3      2022-06-13
# 4      2022-06-10
#           ...
# 6147   2020-01-31
# 6148   2020-01-31
# 6149   2020-01-31
# 6150   2020-01-31
# 6151   2020-01-31
# Name: GAME_DATE, Length: 6152, dtype: datetime64[ns]

# %%
games = games.sort_values('GAME_DATE')

# %%
games
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 6151         Toronto Raptors  0021900720 2020-01-31    TOR @ DET  W
# 6138  Portland Trail Blazers  0021900726 2020-01-31    POR @ LAL  W
# 6139      Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR  L
# 6140          Denver Nuggets  0021900724 2020-01-31    DEN @ MIL  W
# 6141         Milwaukee Bucks  0021900724 2020-01-31  MIL vs. DEN  L
# ...                      ...         ...        ...          ... ..
# 4      Golden State Warriors  0042100404 2022-06-10    GSW @ BOS  W
# 3             Boston Celtics  0042100405 2022-06-13    BOS @ GSW  L
# 2      Golden State Warriors  0042100405 2022-06-13  GSW vs. BOS  W
# 1      Golden State Warriors  0042100406 2022-06-16    GSW @ BOS  W
# 0             Boston Celtics  0042100406 2022-06-16  BOS vs. GSW  L
#
#       PLUS_MINUS
# 6151        13.0
# 6138         8.0
# 6139        -8.0
# 6140        12.0
# 6141       -12.0
# ...          ...
# 4           10.0
# 3          -10.0
# 2           10.0
# 1           13.0
# 0          -13.0
#
# [6152 rows x 6 columns]

# %% [markdown]
# ### Creating a feature to measure how each team performed before the current game, using **PLUS_MINUS**

# %% [markdown]
# **rolling()**: calculate statistics based on a moving window of fixed size(30) <br>
# **closed='left'**: includes 30 records before the current game, but not including the current game

# %% [markdown]
# ### Below code is to **for each team, calculate mean of PLUS_MINUS for the recent 30 games**

# %%
games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

# %%
games[games['TEAM_NAME'] == 'Toronto Raptors'].head(36)
# Out:
#             TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 6151  Toronto Raptors  0021900720 2020-01-31    TOR @ DET  W        13.0
# 6115  Toronto Raptors  0021900740 2020-02-02  TOR vs. CHI  W        27.0
# 6064  Toronto Raptors  0021900758 2020-02-05  TOR vs. IND  W         1.0
# 6052  Toronto Raptors  0021900772 2020-02-07    TOR @ IND  W         9.0
# 6023  Toronto Raptors  0021900781 2020-02-08  TOR vs. BKN  W         1.0
# 6005  Toronto Raptors  0021900796 2020-02-10  TOR vs. MIN  W        11.0
# 5977  Toronto Raptors  0021900809 2020-02-12    TOR @ BKN  L       -10.0
# 5917  Toronto Raptors  0021900829 2020-02-21  TOR vs. PHX  W        17.0
# 5890  Toronto Raptors  0021900843 2020-02-23  TOR vs. IND  W        46.0
# 5871  Toronto Raptors  0021900858 2020-02-25  TOR vs. MIL  L       -11.0
# 5816  Toronto Raptors  0021900879 2020-02-28  TOR vs. CHA  L        -3.0
# 5791  Toronto Raptors  0021900898 2020-03-01    TOR @ DEN  L       -15.0
# 5752  Toronto Raptors  0021900914 2020-03-03    TOR @ PHX  W         9.0
# 5727  Toronto Raptors  0021900929 2020-03-05    TOR @ GSW  W         8.0
# 5687  Toronto Raptors  0021900956 2020-03-08    TOR @ SAC  W         5.0
# 5667  Toronto Raptors  0021900959 2020-03-09    TOR @ UTA  W         9.0
# 5619  Toronto Raptors  0011900111 2020-07-24  TOR vs. HOU  W        11.0
# 5605  Toronto Raptors  0011900121 2020-07-26  TOR vs. POR  W         6.0
# 5581  Toronto Raptors  0011900129 2020-07-28    TOR @ PHX  L       -11.0
# 5548  Toronto Raptors  0021901243 2020-08-01  TOR vs. LAL  W        15.0
# 5531  Toronto Raptors  0021901250 2020-08-03    TOR @ MIA  W         4.0
# 5510  Toronto Raptors  0021901266 2020-08-05    TOR @ ORL  W        10.0
# 5487  Toronto Raptors  0021901279 2020-08-07  TOR vs. BOS  L       -22.0
# 5462  Toronto Raptors  0021901286 2020-08-09  TOR vs. MEM  W         9.0
# 5447  Toronto Raptors  0021901294 2020-08-10    TOR @ MIL  W         8.0
# 5427  Toronto Raptors  0021901305 2020-08-12    TOR @ PHI  W         4.0
# 5402  Toronto Raptors  0021901318 2020-08-14  TOR vs. DEN  W         8.0
# 5392  Toronto Raptors  0041900111 2020-08-17  TOR vs. BKN  W        24.0
# 5375  Toronto Raptors  0041900112 2020-08-19  TOR vs. BKN  W         5.0
# 5361  Toronto Raptors  0041900113 2020-08-21    TOR @ BKN  W        25.0
# 5346  Toronto Raptors  0041900114 2020-08-23    TOR @ BKN  W        28.0
# 5317  Toronto Raptors  0041900211 2020-08-30  TOR vs. BOS  L       -18.0
# 5310  Toronto Raptors  0041900212 2020-09-01  TOR vs. BOS  L        -3.0
# 5301  Toronto Raptors  0041900213 2020-09-03    TOR @ BOS  W         1.0
# 5295  Toronto Raptors  0041900214 2020-09-05    TOR @ BOS  W         7.0
# 5286  Toronto Raptors  0041900215 2020-09-07  TOR vs. BOS  L       -22.0
#
#       avg_30_plus_minus
# 6151                NaN
# 6115                NaN
# 6064                NaN
# 6052                NaN
# 6023                NaN
# 6005                NaN
# 5977                NaN
# 5917                NaN
# 5890                NaN
# 5871                NaN
# 5816                NaN
# 5791                NaN
# 5752                NaN
# 5727                NaN
# 5687                NaN
# 5667                NaN
# 5619                NaN
# 5605                NaN
# 5581                NaN
# 5548                NaN
# 5531                NaN
# 5510                NaN
# 5487                NaN
# 5462                NaN
# 5447                NaN
# 5427                NaN
# 5402                NaN
# 5392                NaN
# 5375                NaN
# 5361                NaN
# 5346           7.100000
# 5317           7.600000
# 5310           6.100000
# 5301           5.966667
# 5295           5.700000
# 5286           5.900000

# %% [markdown]
# ### We see that 'avg_30_plus_minus' has values from 31st row, and this 7.1 value is the mean of PLUS_MINUS values of the first 30 rows

# %% [markdown]
# # Home advantage:
# ## The Home team has an advantage of the opponent team
# ### See MATCHUP column. If TOR vs CHI, Toronto Raptors is the HOME TEAM. Else, other team is the home team

# %%
msk = games['MATCHUP'].str.contains('@')

# %%
games_away = games[msk] 
games_home = games[~msk]

# %%
games_home.shape
# Out:
# (3076, 7)

# %%
games_away.shape
# Out:
# (3076, 7)

# %%
games_home
# Out:
#                   TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  \
# 6139     Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR  L
# 6141        Milwaukee Bucks  0021900724 2020-01-31  MIL vs. DEN  L
# 6143          Brooklyn Nets  0021900721 2020-01-31  BKN vs. CHI  W
# 6150        Detroit Pistons  0021900720 2020-01-31  DET vs. TOR  L
# 6148           Phoenix Suns  0021900725 2020-01-31  PHX vs. OKC  L
# ...                     ...         ...        ...          ... ..
# 8     Golden State Warriors  0042100402 2022-06-05  GSW vs. BOS  W
# 6            Boston Celtics  0042100403 2022-06-08  BOS vs. GSW  W
# 5            Boston Celtics  0042100404 2022-06-10  BOS vs. GSW  L
# 2     Golden State Warriors  0042100405 2022-06-13  GSW vs. BOS  W
# 0            Boston Celtics  0042100406 2022-06-16  BOS vs. GSW  L
#
#       PLUS_MINUS  avg_30_plus_minus
# 6139        -8.0                NaN
# 6141       -12.0                NaN
# 6143        15.0                NaN
# 6150       -13.0                NaN
# 6148        -4.0                NaN
# ...          ...                ...
# 8           19.0           2.533333
# 6           16.0           8.133333
# 5          -10.0           8.366667
# 2           10.0           3.900000
# 0          -13.0           6.033333
#
# [3076 rows x 7 columns]

# %%
games_away
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE    MATCHUP WL  PLUS_MINUS  \
# 6151         Toronto Raptors  0021900720 2020-01-31  TOR @ DET  W        13.0
# 6138  Portland Trail Blazers  0021900726 2020-01-31  POR @ LAL  W         8.0
# 6140          Denver Nuggets  0021900724 2020-01-31  DEN @ MIL  W        12.0
# 6142           Chicago Bulls  0021900721 2020-01-31  CHI @ BKN  L       -15.0
# 6145        Dallas Mavericks  0021900722 2020-01-31  DAL @ HOU  L        -7.0
# ...                      ...         ...        ...        ... ..         ...
# 9             Boston Celtics  0042100402 2022-06-05  BOS @ GSW  L       -19.0
# 7      Golden State Warriors  0042100403 2022-06-08  GSW @ BOS  L       -16.0
# 4      Golden State Warriors  0042100404 2022-06-10  GSW @ BOS  W        10.0
# 3             Boston Celtics  0042100405 2022-06-13  BOS @ GSW  L       -10.0
# 1      Golden State Warriors  0042100406 2022-06-16  GSW @ BOS  W        13.0
#
#       avg_30_plus_minus
# 6151                NaN
# 6138                NaN
# 6140                NaN
# 6142                NaN
# 6145                NaN
# ...                 ...
# 9              9.433333
# 7              3.900000
# 4              3.433333
# 3              7.100000
# 1              3.766667
#
# [3076 rows x 7 columns]

# %%
games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))

# %%
games_merged
# Out:
#              TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0        Los Angeles Lakers  0021900726     2020-01-31  LAL vs. POR       L
# 1           Milwaukee Bucks  0021900724     2020-01-31  MIL vs. DEN       L
# 2             Brooklyn Nets  0021900721     2020-01-31  BKN vs. CHI       W
# 3           Detroit Pistons  0021900720     2020-01-31  DET vs. TOR       L
# 4              Phoenix Suns  0021900725     2020-01-31  PHX vs. OKC       L
# ...                     ...         ...            ...          ...     ...
# 3071  Golden State Warriors  0042100402     2022-06-05  GSW vs. BOS       W
# 3072         Boston Celtics  0042100403     2022-06-08  BOS vs. GSW       W
# 3073         Boston Celtics  0042100404     2022-06-10  BOS vs. GSW       L
# 3074  Golden State Warriors  0042100405     2022-06-13  GSW vs. BOS       W
# 3075         Boston Celtics  0042100406     2022-06-16  BOS vs. GSW       L
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0                -8.0                     NaN  Portland Trail Blazers
# 1               -12.0                     NaN          Denver Nuggets
# 2                15.0                     NaN           Chicago Bulls
# 3               -13.0                     NaN         Toronto Raptors
# 4                -4.0                     NaN   Oklahoma City Thunder
# ...               ...                     ...                     ...
# 3071             19.0                2.533333          Boston Celtics
# 3072             16.0                8.133333   Golden State Warriors
# 3073            -10.0                8.366667   Golden State Warriors
# 3074             10.0                3.900000          Boston Celtics
# 3075            -13.0                6.033333   Golden State Warriors
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-31    POR @ LAL       W              8.0
# 1        2020-01-31    DEN @ MIL       W             12.0
# 2        2020-01-31    CHI @ BKN       L            -15.0
# 3        2020-01-31    TOR @ DET       W             13.0
# 4        2020-01-31    OKC @ PHX       W              4.0
# ...             ...          ...     ...              ...
# 3071     2022-06-05    BOS @ GSW       L            -19.0
# 3072     2022-06-08    GSW @ BOS       L            -16.0
# 3073     2022-06-10    GSW @ BOS       W             10.0
# 3074     2022-06-13    BOS @ GSW       L            -10.0
# 3075     2022-06-16    GSW @ BOS       W             13.0
#
#       avg_30_plus_minus_away
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 3071                9.433333
# 3072                3.900000
# 3073                3.433333
# 3074                7.100000
# 3075                3.766667
#
# [3076 rows x 13 columns]

# %%
games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home']-games_merged['avg_30_plus_minus_away']

# %%
games_merged
# Out:
#              TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0        Los Angeles Lakers  0021900726     2020-01-31  LAL vs. POR       L
# 1           Milwaukee Bucks  0021900724     2020-01-31  MIL vs. DEN       L
# 2             Brooklyn Nets  0021900721     2020-01-31  BKN vs. CHI       W
# 3           Detroit Pistons  0021900720     2020-01-31  DET vs. TOR       L
# 4              Phoenix Suns  0021900725     2020-01-31  PHX vs. OKC       L
# ...                     ...         ...            ...          ...     ...
# 3071  Golden State Warriors  0042100402     2022-06-05  GSW vs. BOS       W
# 3072         Boston Celtics  0042100403     2022-06-08  BOS vs. GSW       W
# 3073         Boston Celtics  0042100404     2022-06-10  BOS vs. GSW       L
# 3074  Golden State Warriors  0042100405     2022-06-13  GSW vs. BOS       W
# 3075         Boston Celtics  0042100406     2022-06-16  BOS vs. GSW       L
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0                -8.0                     NaN  Portland Trail Blazers
# 1               -12.0                     NaN          Denver Nuggets
# 2                15.0                     NaN           Chicago Bulls
# 3               -13.0                     NaN         Toronto Raptors
# 4                -4.0                     NaN   Oklahoma City Thunder
# ...               ...                     ...                     ...
# 3071             19.0                2.533333          Boston Celtics
# 3072             16.0                8.133333   Golden State Warriors
# 3073            -10.0                8.366667   Golden State Warriors
# 3074             10.0                3.900000          Boston Celtics
# 3075            -13.0                6.033333   Golden State Warriors
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-31    POR @ LAL       W              8.0
# 1        2020-01-31    DEN @ MIL       W             12.0
# 2        2020-01-31    CHI @ BKN       L            -15.0
# 3        2020-01-31    TOR @ DET       W             13.0
# 4        2020-01-31    OKC @ PHX       W              4.0
# ...             ...          ...     ...              ...
# 3071     2022-06-05    BOS @ GSW       L            -19.0
# 3072     2022-06-08    GSW @ BOS       L            -16.0
# 3073     2022-06-10    GSW @ BOS       W             10.0
# 3074     2022-06-13    BOS @ GSW       L            -10.0
# 3075     2022-06-16    GSW @ BOS       W             13.0
#
#       avg_30_plus_minus_away  avg_30_plus_minus_diff
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 3071                9.433333               -6.900000
# 3072                3.900000                4.233333
# 3073                3.433333                4.933333
# 3074                7.100000               -3.200000
# 3075                3.766667                2.266667
#
# [3076 rows x 14 columns]

# %%
games_model = games_merged[['WL_home','avg_30_plus_minus_diff']].dropna()

# %%
games_model
# Out:
#      WL_home  avg_30_plus_minus_diff
# 398        L               -6.233333
# 399        L               -5.366667
# 400        W                1.933333
# 402        W                2.466667
# 403        L               -8.066667
# ...      ...                     ...
# 3071       W               -6.900000
# 3072       W                4.233333
# 3073       L                4.933333
# 3074       W               -3.200000
# 3075       L                2.266667
#
# [2568 rows x 2 columns]

# %%
games_model['WL_home'] = games_model['WL_home'].map({'W':1, 'L' :0})

# %%
games_model
# Out:
#       WL_home  avg_30_plus_minus_diff
# 398         0               -6.233333
# 399         0               -5.366667
# 400         1                1.933333
# 402         1                2.466667
# 403         0               -8.066667
# ...       ...                     ...
# 3071        1               -6.900000
# 3072        1                4.233333
# 3073        0                4.933333
# 3074        1               -3.200000
# 3075        0                2.266667
#
# [2568 rows x 2 columns]

# %% [markdown]
# # Building the model

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(games_model, stratify=games_model['WL_home'], test_size=0.2, random_state=7)

# %%
df_train.shape
# Out:
# (2054, 2)

# %%
df_test.shape
# Out:
# (514, 2)

# %%
target = 'WL_home'
X_train = df_train.drop(columns=target) #avg_plus_minus_diff
y_train = df_train[target] #WL_home

X_test = df_test.drop(columns=target) #avg_plus_minus_diff
y_test = df_test[target] #WL_home

# %% [markdown]
# ## We use XGBoost to show the general steps of modelling. XGBoost is a popular gradient boosting library, it is easy to use, fast to run and often gives good performance

# %%
# %pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\sandh\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: scipy in c:\users\sandh\appdata\roaming\python\python39\site-packages (from xgboost) (1.8.1)
# Requirement already satisfied: numpy in c:\users\sandh\anaconda3\lib\site-packages (from xgboost) (1.22.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# %%
clf=xgb.XGBClassifier(use_label_encoder=False, random_state=7)

# %%
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=7,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5778210116731517

# %% [markdown]
# ## Tune hyperparameters using randomsearch: hyperparameters values are set before the learning process begins

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.fixes import loguniform

# %%
hyp_params={'learning_rate':loguniform(0.0001, 1),
            'max_depth':[2,3,4,5,6,7,8,9],
            'subsample':[0.7, 0.8, 0.9, 1.0],
            'n_estimators':[50, 100, 150, 200]}

# %%
random_hyp = RandomizedSearchCV(estimator=clf, 
                               param_distributions=hyp_params,
                               n_iter=20,
                               cv=7,
                               scoring='accuracy',
                               random_state=7)

# %%
random_hyp.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=7,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            callbacks=None, colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, gamma=0, gpu_id=-1,
#                                            grow_policy='depthwise',
#                                            importance_type=None,
#                                            interaction_constraints='',
#                                            learning_rate=0.300000012,
#                                            max_bin=256,...
#                                            n_estimators=100, n_jobs=0,
#                                            num_parallel_tree=1,
#                                            predictor='auto', random_state=7,
#                                            reg_alpha=0, reg_lambda=1, ...),
#                    n_iter=20,
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000014A98993D30>,
#                                         'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
#                                         'n_estimators': [50, 100, 150, 200],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=7, scoring='accuracy')

# %%
random_hyp.best_params_
# Out:
# {'learning_rate': 0.014255533717547383,
#  'max_depth': 2,
#  'n_estimators': 100,
#  'subsample': 0.9}

# %%
model_hyp = random_hyp.best_estimator_

# %%
y_pred_hyp = model_hyp.predict(X_test)

# %%
accuracy_score(y_test, y_pred_hyp)
# Out:
# 0.6303501945525292

# %% [markdown]
# ## Dumping and loading model_hyp. model_saved and model_hyp are the same.

# %%
from joblib import dump, load

# %%
dump(model_hyp, 'model_nba.joblib')
# Out:
# ['model_nba.joblib']

# %%
model_saved = load('model_nba.joblib')

# %% [markdown]
# We find that the accuracy is the same as previous

# %%
accuracy_score(y_test, model_saved.predict(X_test))
# Out:
# 0.6303501945525292

# %% [markdown]
# # What should the API do?

# %% [markdown]
# ## Take a home team and an away team, and return a prediciton result of the winning team

# %%
team_home = 'Toronto Raptors'
team_away = 'Boston Celtics'

# %%
def predict_games(team_home, team_away):
    #Copied from above
    from nba_api.stats.endpoints import leaguegamefinder
    gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2021', league_id_nullable='00') 
    games = gamefinder.get_data_frames()[0]

    games = games[['TEAM_NAME', 'GAME_ID',
           'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

    import pandas as pd

    games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

    #Most recent 30 games by date, for Toronto Raptors
    msk_home = (games['TEAM_NAME']==team_home)
    games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
    home_plus_minus = games_30_home['PLUS_MINUS'].mean()

    #Most recent 30 games by date, for Boston Celtics
    msk_away = (games['TEAM_NAME']==team_away)
    games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
    away_plus_minus = games_30_away['PLUS_MINUS'].mean()


    # games = games.sort_values('GAME_DATE')

    # games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

    # msk = games['MATCHUP'].str.contains('@')
    # games_away = games[msk]
    # games_home = games[~msk]

    # games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))


    # games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home']-games_merged['avg_30_plus_minus_away']

    games_diff = home_plus_minus - away_plus_minus

    model_saved = load('model_nba.joblib')

    import numpy as np

    predict_home_win = model_saved.predict(np.array([games_diff]))[0]

    predict_winning_probability = model_saved.predict_proba(np.array([games_diff]))[0][1]
    
    return predict_home_win, predict_winning_probability

# %%
predict_games('Toronto Raptors', 'Boston Celtics')
# Out:
# (0, 0.42300433)
